# %%
import requests

def google_search(query, api_key, cx):
    url = f"https://www.googleapis.com/customsearch/v1?key={api_key}&cx={cx}&q={query}"
    response = requests.get(url)
    results = response.json()
    return results

if __name__ == "__main__":
    # Replace 'YOUR_API_KEY' and 'YOUR_CX' with your actual API key and custom search engine ID
    api_key = "AIzaSyBrpmmBojZVjibtRJbzij81UCqAXVjItts"
    cx = "455cb74e9de5b4920"
    
    query = input("Enter your search query: ")
    search_results = google_search(query, api_key, cx)
    
    if 'items' in search_results:
        print("Search results:")
        for index, item in enumerate(search_results['items'], start=1):
            print(f"{index}. {item['title']}: {item['link']}")
    else:
        print("No search results found.")
# Out:
# Search results:
# 1. HRio | LinkedIn: https://www.linkedin.com/products/syscom-softech-hrio/
# 2. HRIO (@hriosy) • Instagram photos and videos: https://www.instagram.com/hriosy/
# 3. About HRIO | ITAC Website: https://www.sna-itac.com/about-itac
# 4. HEALTH RECORDS INFORMATION OFFICER (HRIO) Duties and ...: https://www.stbridgethospital.co.ke/docs/1620854660HEALTH_RECORDS_INFORMATION_OFFICER_HRIO_.pdf
# 5. Croatian Sustainability Index (HRIO) | One Planet network: https://www.oneplanetnetwork.org/knowledge-centre/projects/croatian-sustainability-index-hrio
# 6. HRIO - What does HRIO stand for? The Free Dictionary: https://acronyms.thefreedictionary.com/HRIO
# 7. Unscramble HRIO - Unscrambled 9 words from letters in HRIO: https://www.wordunscrambler.net/unscramble/hrio
# 8. Hrvatski indeks održivosti – HRIO: https://hrpsor.hr/hrio
# 9. zvol for swap and sync=? · Issue #229 · zfsonlinux/pkg-zfs · GitHub: https://github.com/zfsonlinux/pkg-zfs/issues/229
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from urllib import robotparser
import queue
import time

class Crawler:
    def __init__(self, seed_url, limit=10, delay=2, user_agent='Mozilla/5.0'):
        self.seed_url = seed_url
        self.url_queue = queue.Queue()
        self.seen_urls = set()
        self.url_queue.put(seed_url)
        self.limit = limit
        self.crawled_count = 0  
        self.delay = delay
        self.user_agent = user_agent
        self.robots = {}

    def crawl(self):
        while not self.url_queue.empty() and self.crawled_count < self.limit:  
            url = self.url_queue.get()
            if url in self.seen_urls:
                continue
            self.seen_urls.add(url)
            try:
                html = self.fetch_html(url)
                if html:
                    self.parse_and_enqueue(url, html)
                    self.crawled_count += 1  
            except requests.exceptions.RequestException as e:
                print(f"Error crawling {url}: {e}")
            time.sleep(self.delay)  

    def fetch_html(self, url):
        try:
            response = requests.get(url, headers={'User-Agent': self.user_agent}, timeout=10)
            response.raise_for_status()  
            return response.text
        except requests.exceptions.RequestException as e:
            print(f"Error fetching {url}: {e}")
            return None

    def parse_and_enqueue(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        domain = urlparse(url).netloc
        self.respect_robots_txt(domain)
        for link in soup.find_all('a'):
            link_url = link.get('href')
            if link_url and link_url.startswith('http'):
                absolute_url = urljoin(url, link_url)
                if self.is_allowed(absolute_url, domain) and absolute_url not in self.seen_urls:  
                    self.url_queue.put(absolute_url)
        print(f"Crawled: {url}")

    def respect_robots_txt(self, domain):
        if domain not in self.robots:
            robots_url = urljoin(self.seed_url, '/robots.txt')
            rp = robotparser.RobotFileParser()
            rp.set_url(robots_url)
            rp.read()
            self.robots[domain] = rp

    def is_allowed(self, url, domain):
        rp = self.robots[domain]
        return rp.can_fetch(self.user_agent, url)

    def search(self, query):
        print("Search results:")
        result_count = 0
        while not self.url_queue.empty() and result_count < self.limit:
            url = self.url_queue.get()
            try:
                html = self.fetch_html(url)
                if html and query.lower() in html.lower():
                    result_count += 1
                    print(f"{result_count}. {self.get_title(url)}: {url}")
            except requests.exceptions.RequestException as e:
                print(f"Error fetching {url}: {e}")

    def get_title(self, url):
        try:
            response = requests.get(url, headers={'User-Agent': self.user_agent}, timeout=10)
            response.raise_for_status()  
            soup = BeautifulSoup(response.text, 'html.parser')
            title_tag = soup.find('title')
            if title_tag:
                return title_tag.text.strip()
            else:
                return "No Title"
        except requests.exceptions.RequestException:
            return "Error fetching title"

# Define seed URL
seed_url = "https://www.example.com"

# Create crawler instance
crawler = Crawler(seed_url, limit=10)

# Start crawling
crawler.crawl()

# Perform a search
query = "example query"
crawler.search(query)
# Out:
# Crawled: https://www.example.com
# Crawled: https://www.iana.org/domains/example
# Error fetching http://pti.icann.org: HTTPConnectionPool(host='pti.icann.org', port=80): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x11df8d6a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Crawled: http://www.icann.org/
# Crawled: https://www.icann.org/privacy/policy
# Crawled: https://www.icann.org/privacy/tos
# Crawled: http://www.icann.org
# Crawled: https://account.icann.org/logout?app_id=0oa9o9k9rp8VUcyJL2p7
# Crawled: https://meetings.icann.org/en/meetings/icann80/
# Crawled: https://www.icann.org/ceosearch
# Crawled: https://www.icann.org/en/blogs/details/the-icann-grant-program-now-accepting-applications-25-03-2024-en
# Search results:
# Error fetching https://twitter.com/icann: 400 Client Error: Bad Request for url: https://twitter.com/icann
# ...

# %%
import ollama
import bs4
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import OllamaEmbeddings
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# 1. Load the data
loader = WebBaseLoader(
    web_paths=("https://mer.vin/2024/04/llama-3-rag-using-ollama/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
docs = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)

# 2. Create Ollama embeddings and vector store
embeddings = OllamaEmbeddings(model="llama3")
vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings)

# 3. Call Ollama Llama3 model
def ollama_llm(question, context):
    formatted_prompt = f"Question: {question}\n\nContext: {context}"
    response = ollama.chat(model='llama3', messages=[{'role': 'user', 'content': formatted_prompt}])
    return response['message']['content']

# 4. RAG Setup
retriever = vectorstore.as_retriever()
def combine_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)
def rag_chain(question):
    retrieved_docs = retriever.invoke(question)
    formatted_context = combine_docs(retrieved_docs)
    return ollama_llm(question, formatted_context)

# 5. Use the RAG App
result = rag_chain("What is Task Decomposition?")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 25
#      23 # 2. Create Ollama embeddings and vector store
#      24 embeddings = OllamaEmbeddings(model="llama3")
# ---> 25 vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings)
#      27 # 3. Call Ollama Llama3 model
#      28 def ollama_llm(question, context):
#
# File ~/Documents/WORK/PROJECT/Minor-Project/.venv/lib/python3.12/site-packages/langchain_community/vectorstores/chroma.py:790, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     788 texts = [doc.page_content for doc in documents]
#     789 metadatas = [doc.metadata for doc in documents]
# --> 790 return cls.from_texts(
#     791     texts=texts,
#     792     embedding=embedding,
#     793     metadatas=metadatas,
# ...

# %%
from googlesearch import Search

# %%
python_results = Search("How is the weather in Tokyo")

# %%
python_results.results
# Out:
# [<SearchResult title="Tokyo, Tokyo, Japan Weather Forecast - AccuWeather" (Tokyo, Tokyo, Japan Weather Forecast - AccuWeatherwww.accuweather.com › tokyo › weather-forecast)>,
#  <SearchResult title="10-Day Weather Forecast for Minato-ku, Tokyo Prefecture, Japan" (10-Day Weather Forecast for Minato-ku, Tokyo Prefecture, Japanweather.com › weather › tenday › Minato+ku+Tokyo+Prefecture+Japan)>,
#  <SearchResult title="Tokyo, Japan 14 day weather forecast - Time and Date" (Tokyo, Japan 14 day weather forecast - Time and Datewww.timeanddate.com › Weather › Japan › Tokyo)>,
#  <SearchResult title="Weather for Tokyo, Japan - Time and Date" (Weather for Tokyo, Japan - Time and Datewww.timeanddate.com › Weather › Japan)>,
#  <SearchResult title="Tokyo - BBC Weather" (Tokyo - BBC Weatherwww.bbc.com › weather)>,
#  <SearchResult title="Tokyo, Tokyo, Japan Current Weather | AccuWeather" (Tokyo, Tokyo, Japan Current Weather | AccuWeatherwww.accuweather.com › tokyo › current-weather)>,
# ...

# %%
a=python_results.related_searches

# %%
for i in a:
    print(i)
# Out:
# <Search query="Tokyo weather by month" results=(Not loaded)>
# <Search query="Osaka weather" results=(Not loaded)>
# <Search query="Weather Kyoto" results=(Not loaded)>
# <Search query="Weather in Tokyo tomorrow" results=(Not loaded)>
# <Search query="How is the weather in tokyo today" results=(Not loaded)>
# <Search query="Weather in Tokyo 10 days" results=(Not loaded)>
# <Search query="Tokyo weather forecast 30 days" results=(Not loaded)>
# <Search query="Tokyo weather forecast 14 days" results=(Not loaded)>

# %%
from googlesearch import Search
import requests

# Step 1: Search URLs
def search_urls(query):
    search_results = Search(query)
    urls = [result.url for result in search_results.results[:5]]  # Get top 5 URLs
    return urls

# Step 2: Retrieve Web Content
def fetch_web_content(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return response.text
        else:
            return None
    except Exception as e:
        print(f"Error fetching content from {url}: {str(e)}")
        return None

# Step 3: Preprocess Content (Not implemented here, can be done using BeautifulSoup or similar libraries)

# Step 4: Fine-Tune Language Model (Not implemented here, you can use Hugging Face's transformers library)

# Step 5: Generate Results
def generate_results(query):
    urls = search_urls(query)
    for url in urls:
        content = fetch_web_content(url)
        if content:
            # Preprocess content (if needed)
            # Fine-tune language model (using Hugging Face's transformers or similar)
            # Generate results based on the query and fine-tuned model
            print(f"Results for {url}:")
            # Example: print generated text
            print("Generated text based on fine-tuned model...")
            print("-" * 50)
        else:
            print(f"Failed to fetch content from {url}")

# Example usage
query = "who is ELon musk"
generate_results(query)
# Out:
# Results for https://en.wikipedia.org/wiki/Elon_Musk:
# Generated text based on fine-tuned model...
# --------------------------------------------------
# Error fetching content from who is ELon musk: Invalid URL 'who is ELon musk': No scheme supplied. Perhaps you meant https://who is ELon musk?
# Failed to fetch content from who is ELon musk
# Failed to fetch content from https://www.investopedia.com/articles/personal-finance/061015/how-elon-musk-became-elon-musk.asp
# Results for https://www.britannica.com/money/Elon-Musk:
# Generated text based on fine-tuned model...
# --------------------------------------------------
# Results for https://www.forbes.com/profile/elon-musk/:
# Generated text based on fine-tuned model...
# --------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
from googlesearch import Search
from langchain_community.llms import Ollama

def fetch_search_results(query):
    # Fetch search results from Google
    search_results = Search(query)
    urls = [result.url for result in search_results.results[:5]]
    print(urls)
    return urls

def scrape_search_results(search_results):
    # Scrape search results from URLs
    results_data = []
    for url in search_results:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.title.string if soup.title else "No title"
        description_tag = soup.find('meta', attrs={'name': 'description'})
        description = description_tag['content'] if description_tag else "No description"
        result = {'title': title, 'url': url, 'description': description}
        results_data.append(result)
    return results_data

def generate_prompt(query, search_results):
    # Initialize Ollama model
    ollama = Ollama(model="llama3")

    # Initialize the prompt with the search query
    prompt = f"Summarize the following webpages about '{query}':\n"

    # Add each webpage's title and URL to the prompt
    for idx, result in enumerate(search_results, start=1):
        prompt += f"\nWebpage {idx}:\nTitle: {result['title']}\nURL: {result['url']}\n"

    # Add a message to instruct Ollama to generate a summary
    prompt += "\nPlease generate a wonderful summary by compiling information from these webpages."

    return prompt

def generate_output(prompt):
    # Initialize Ollama model
    ollama = Ollama(model="llama3")

    # Generate output using Ollama
    output = ollama.invoke(prompt)
    return output

def main():
    query = input("Enter your search query: ")
    search_results = fetch_search_results(query)
    search_results_data = scrape_search_results(search_results)
    prompt = generate_prompt(query, search_results_data)
    output = generate_output(prompt)
    print(output)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/WORK/PROJECT/Minor-Project/.venv/lib/python3.12/site-packages/googlesearch/googlesearch.py:76, in Search.load(self)
#      75 _related_history = []
# ---> 76 for associate in website.find("div", {"id": "main"}).find_all("div", recursive=False)[-1].find("div").find_all("div"):
#      77     if len(associate.find_all("a")) >= 1:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
#
# During handling of the above exception, another exception occurred:
#
# RelatedSearchError                        Traceback (most recent call last)
# Cell In[2], line 59
#      56     print(output)
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[2], line 52, in main()
#      50 def main():
#      51     query = input("Enter your search query: ")
# ...

# %%
import requests
from bs4 import BeautifulSoup
from googlesearch import Search
from langchain_community.llms import Ollama
import validators

def fetch_search_results(query):
    # Fetch search results from Google
    search = Search(query)
    urls = [result.url for result in search.results[:1]]
    print("Search Results URLs:", urls)
    return urls

def scrape_search_results(urls):
    # Scrape search results from URLs
    results_data = []
    for url in urls:
        if validators.url(url):
            try:
                response = requests.get(url)
                soup = BeautifulSoup(response.text, 'html.parser')
                title = soup.title.string if soup.title else "No title"
                description_tag = soup.find('meta', attrs={'name': 'description'})
                description = description_tag['content'] if description_tag else "No description"
                result = {'title': title, 'url': url, 'description': description}
                results_data.append(result)
            except Exception as e:
                print(f"Error scraping {url}: {e}")
        else:
            print(f"Invalid URL: {url}")
    return results_data

def generate_prompt(query, search_results):
    # Initialize the prompt with the search query
    prompt = f"Summarize the following webpages about '{query}':\n\n"

    # Add each webpage's title and URL to the prompt
    for idx, result in enumerate(search_results, start=1):
        prompt += f"Webpage {idx}:\nTitle: {result['title']}\nURL: {result['url']}\n\n"

    # Add a message to instruct Ollama to generate a summary
    prompt += "Please generate a wonderful summary by compiling information from these webpages."

    return prompt

def generate_output(prompt):
    # Initialize Ollama model
    ollama = Ollama(model="llama3")

    # Generate output using Ollama
    output = ollama.invoke(prompt)
    return output

def main():
    query = input("Enter your search query: ")
    search_results = fetch_search_results(query)
    search_results_data = scrape_search_results(search_results)
    prompt = generate_prompt(query, search_results_data)
    output = generate_output(prompt)
    print("\nGenerated Summary:\n", output)

if __name__ == "__main__":
    main()
# Out:
# Search Results URLs: ['https://www.python.org/']
#
# Generated Summary:
#  I'm happy to help! However, I notice that you've only provided one webpage URL, which is the official Python website (https://www.python.org/). There's no second webpage to summarize.
#
# But don't worry! I can still provide a summary of the information on this webpage:
#
# **Welcome to Python.org**
#
# The official Python website provides an overview of the language, its features, and its community. Here are some key points summarized from the webpage:
#
# * **What is Python?**: Python is a high-level, interpreted programming language that is easy to learn and understand.
# * **History**: Python was created in the late 1980s by Guido van Rossum and has since become one of the most popular programming languages worldwide.
# * **Features**: Python is known for its simplicity, readability, and ease of use. Its features include:
# 	+ Indentation-based syntax
# 	+ Dynamic typing
# 	+ Large standard library
# ...
